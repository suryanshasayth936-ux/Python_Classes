# %% [markdown]
# <a href="https://colab.research.google.com/github/suryanshasayth936-ux/Python_Classes/blob/main/Class_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dct = {
    'name' : ['Tom', 'Nick', 'Krish', 'Jack'],
    'age' : [20, 21, 19, 18],
    'roll' : [1, 2, 3, 4]
}

df = pd.DataFrame(dct, index = ['a','b','c','d'])
display(df)
# Out:
#     name  age  roll
# a    Tom   20     1
# b   Nick   21     2
# c  Krish   19     3
# d   Jack   18     4

# %%
df = pd.read_csv('student_data.csv')
display(df)
df.head() #displays the first 5 values
df.tail() #displays last 5 values
df.shape #outputs (rows,colums)
df.info() #data about data, like gives information about the information
df.describe()
#25% - > First Quarterly
#50% - > Second Quarterly
#75% - > Third Quarterly
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
display(df.columns) #list of columns
display(df.index) #range of indices
# Out:
# Index(['study_hours', 'attendance', 'sleep_hours', 'internet_usage',
#        'assignments_completed', 'previous_score', 'exam_score',
#        'placement_status'],
#       dtype='object')
# RangeIndex(start=0, stop=10000, step=1)

# %%
display(df[['study_hours', 'internet_usage']])
display(df[['study_hours']])
display(df.study_hours)
# Out:
#       study_hours  internet_usage
# 0               7               7
# 1               4               3
# 2              11               6
# 3               8               8
# 4               5               6
# ...           ...             ...
# 9995            2               7
# 9996            7               9
# 9997           10               5
# 9998           10               5
# 9999            2              11
#
# [10000 rows x 2 columns]
#       study_hours
# 0               7
# 1               4
# 2              11
# 3               8
# 4               5
# ...           ...
# 9995            2
# 9996            7
# 9997           10
# 9998           10
# 9999            2
#
# [10000 rows x 1 columns]
# 0        7
# 1        4
# 2       11
# 3        8
# 4        5
#         ..
# 9995     2
# 9996     7
# 9997    10
# 9998    10
# 9999     2
# Name: study_hours, Length: 10000, dtype: int64

# %%
display(df.iloc[5:22])

df.loc[df['study_hours']==11, ['study_hours', 'sleep_hours']].iloc[4:8]
#study loc and iloc in depth
# Out:
#     study_hours  attendance  sleep_hours  internet_usage  \
# 5             7          40            9              10
# 6            10          40            4              11
# 7             3          86            7               3
# 8             7          72            8               5
# 9            11          77            4               9
# 10           11          64            8               8
# 11            8          65            5               6
# 12            5          52            6               9
# 13            4          98            9               2
# 14            8          67            8              11
# 15            8          72            7               9
# 16            3          76            8              10
# 17            6          80            8              10
# 18            5          69            8               6
# 19            2          96            8               9
# ...

# %%
d2f = df.loc[df['assignments_completed'] == 8].iloc[1]
display(d2f)
# Out:
# study_hours                   5
# attendance                   52
# sleep_hours                   8
# internet_usage                6
# assignments_completed         8
# previous_score               40
# exam_score                78.82
# placement_status         Placed
# Name: 4, dtype: object

# %%
df = pd.read_csv('student_data.csv')
df[df['assignments_completed']>3]
df["age"] = 20
# display(df)
df.rename(columns = {'assignments_completed':'assign_completed'}, inplace = True) #rename a column
display(df)
df.drop(columns = ['sleep_hours','internet_usage'])
df["dummy_data"] = " "
display(df)
# df.dropna(['dummy_data'])
#isnull, notnull, fillna, unique,
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 3               8          99            9               8                 4
# 4               5          52            8               6                 8
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...
