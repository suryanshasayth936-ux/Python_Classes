# %% [markdown]
# <a href="https://colab.research.google.com/github/suryanshasayth936-ux/Python_Classes/blob/main/Class_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a,b):
  print(a+b)

x=int(input("Enter first number:- "))
y=int(input("Enter second number:- "))
add(x,y)
# Out:
# Enter first number:- 4
# Enter second number:- 8
# 12

# %%
a=int(input("Enter first Number:_ "))
b=int(input("Enter second Number:_ "))
x = lambda a,b: a+b
print(x(a,b))
# Out:
# Enter first Number:_ 5
# Enter second Number:_ 9
# 14

# %% [markdown]
# Enter first Number:_ 5
# Enter second Number:_ 9
# <function <lambda> at 0x7983c8c5a200>

# %%
#String
st = " "
print(len(st))
# Out:
# 1

# %%
st2 = "sUryAnsh sEth"

print(st2.upper())
print(st2.lower())
print(st2.title())
print(st2.capitalize())
print(st2.strip())
# Out:
# SURYANSH SETH
# suryansh seth
# Suryansh Seth
# Suryansh seth
# sUryAnsh sEth

# %%
firstname = ' Suryansh '
lastname = ' Seth here'

print(str(firstname.strip()+lastname))
# Out:
# Suryansh Seth here

# %%
s = "today"
q = "weather"
r = "is GooD"
p = s.title() +" "+ q +" "+ r.lower()
print(p)

print(p.replace("good","bad"))
print(p)
print(p.find("weather"))
# Out:
# Today weather is good
# Today weather is bad
# Today weather is good
# 6

# %%
s = "Hello World"
print(s[-6:-1])
# Out:
#  Worl

# %%
#Sets

st = {2,2,23,2,1}
print(st)
# Out:
# {1, 2, 23}

# %% [markdown]
# Study all functions of sets

# %%
#Dictionary

dct = {"name":"Ramesh",
       "age":23,
       "occupation":"Sstudent",
       "class":19,
       "Roll.No":25

}
print(dct)
print(dct["name"])
# Out:
# {'name': 'Ramesh', 'age': 23, 'occupation': 'Sstudent', 'class': 19, 'Roll.No': 25}
# Ramesh
